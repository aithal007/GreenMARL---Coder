# %% [markdown]
# # GreenMARL-Coder — GRPO smoke on TRL + OpenEnv-style tool env
#
# Runtime: **GPU** (T4 or better recommended). `trl` + model download is heavy on CPU.
#
# This runs `training/grpo_coding_gym.py --smoke` to verify the pipeline. For a real run, remove `--smoke` and increase `--max-steps`.

# %%
# %%capture
# Option A: upload this repo in Colab, then run cells from repo root.
# Option B: !git clone https://github.com/aithal007/GreenMARL---Coder.git
# %pip install -q -r requirements.txt
# %pip install -q -r requirements-train.txt

# %%
import os
os.environ["USE_TORCH"] = "1"
os.environ["USE_TF"] = "0"

import torch
print("cuda:", torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else None)

# %%
import os
import subprocess
import sys
from pathlib import Path

root = Path.cwd()
if not (root / "training" / "grpo_coding_gym.py").is_file():
    raise SystemExit("Run this notebook with cwd = repo root (folder containing `training/`)")
env = {**os.environ, "USE_TORCH": "1", "USE_TF": "0"}
subprocess.check_call([sys.executable, str(root / "training" / "grpo_coding_gym.py"), "--smoke"], cwd=root, env=env)
